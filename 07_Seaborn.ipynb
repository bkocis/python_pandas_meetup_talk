# %% [markdown]
# #Seaborn
# ####One of the libraries that is mentioned as a prt of the pandas ecosystem
#
# http://pandas.pydata.org/pandas-docs/stable/ecosystem.html
#
# ####Take a look at the gallery:
#
# http://stanford.edu/~mwaskom/software/seaborn/examples/index.html
#
# ###plotting library
# ####"Seaborn is a library for making attractive and informative statistical graphics in Python. It is built on top of matplotlib and tightly integrated with the PyData stack, including support for numpy and pandas data structures and statistical routines from scipy and statsmodels."
#
# http://stanford.edu/~mwaskom/software/seaborn/introduction.html
#
# ####Linux easy install with pip

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pa
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pa.read_json('/home/mnost/Documents/ipynotebook/pandas_/data_demo/df_send1_added_isotope_geo_Anita.json')

# %%
k1=df[['vol','sz 002','sz 030','iso_str']]

# %%
with sns.axes_style("white"):
    sns.jointplot(k1['vol'],k1['sz 002'], kind='hex',xlim=([525,534]),ylim=([0,1400]))

# %%
with sns.axes_style("white"):
    sns.jointplot(k1['vol'],k1['sz 002'], kind='kde',xlim=([525,534]),ylim=([0,1400]))

# %%
mpl.rc("figure",figsize=(6,6))
sns.kdeplot(k1,shade=True)

# %%
sns.kdeplot(k1['vol'])

# %%
sns.violinplot(k1['vol'])

# %%
k1.columns
# Out:
# Index([u'vol', u'sz 002', u'sz 030', u'iso_str'], dtype='object')

# %%
sns.violinplot(k1[['sz 002','sz 030']])
