# %% [markdown]
# ##Basic plots in pandas and an example

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
import pandas as pa
from scipy import stats

# %%
cars = pa.read_csv(os.path.join('data','cars.csv'))
cars = cars.dropna()

# %%
cars
# Out:
#                                type   mpg  cyl  disp   hp    wt  speed  wt.1
# 0           AMC Ambassador Brougham  13.0    8   360  175  3821   11.0    73
# 1                AMC Ambassador DPL  15.0    8   390  190  3850    8.5    70
# 2                AMC Ambassador SST  17.0    8   304  150  3672   11.5    72
# 3                  AMC Concord DL 6  20.2    6   232   90  3265   18.2    79
# 4                    AMC Concord DL  18.1    6   258  120  3410   15.1    78
# 6                       AMC Concord  19.4    6   232   90  3210   17.2    78
# 7                       AMC Concord  24.3    4   151   90  3003   20.1    80
# 8                       AMC Gremlin  18.0    6   232  100  2789   15.0    73
# 9                       AMC Gremlin  19.0    6   232  100  2634   13.0    71
# 10                      AMC Gremlin  20.0    6   232  100  2914   16.0    75
# 11                      AMC Gremlin  21.0    6   199   90  2648   15.0    70
# 12    AMC Hornet Sportabout (Wagon)  18.0    6   258  110  2962   13.5    71
# 13                       AMC Hornet  18.0    6   199   97  2774   15.5    70
# 14                       AMC Hornet  18.0    6   232  100  2945   16.0    73
# 15                       AMC Hornet  19.0    6   232  100  2901   16.0    74
# 16                       AMC Hornet  22.5    6   232   90  3085   17.6    76
# 17              AMC Matador (Wagon)  14.0    8   304  150  4257   15.5    74
# 18              AMC Matador (Wagon)  15.0    8   304  150  3892   12.5    72
# 19                      AMC Matador  14.0    8   304  150  3672   11.5    73
# 20                      AMC Matador  15.0    6   258  110  3730   19.0    75
# 21                      AMC Matador  15.5    8   304  120  3962   13.9    76
# 22                      AMC Matador  16.0    6   258  110  3632   18.0    74
# 23                      AMC Matador  18.0    6   232  100  3288   15.5    71
# 24                    AMC Pacer D/L  17.5    6   258   95  3193   17.8    76
# 25                        AMC Pacer  19.0    6   232   90  3211   17.0    75
# 27                    AMC Rebel SST  16.0    8   304  150  3433   12.0    70
# 28                    AMC Spirit DL  27.4    4   121   80  2670   15.0    79
# 29                      Audi 100 LS  20.0    4   114   91  2582   14.0    73
# 30                      Audi 100 LS  23.0    4   115   95  2694   15.0    75
# 31                      Audi 100 LS  24.0    4   107   90  2430   14.5    70
# 32                        Audi 4000  34.3    4    97   78  2188   15.8    80
# 33                        Audi 5000  20.3    5   131  103  2830   15.9    78
# 34              Audi 5000S (Diesel)  36.4    5   121   67  2950   19.9    80
# 35                         Audi Fox  29.0    4    98   83  2219   16.5    74
# 36                         BMW 2002  26.0    4   121  113  2234   12.5    70
# 37                         BMW 320i  21.5    4   121  110  2600   12.8    77
# 38                Buick Century 350  13.0    8   350  175  4100   13.0    73
# 39            Buick Century Limited  25.0    6   181  110  2945   16.4    82
# 40      Buick Century Luxus (Wagon)  13.0    8   350  150  4699   14.5    74
# 41            Buick Century Special  20.6    6   231  105  3380   15.8    78
# 42                    Buick Century  17.0    6   231  110  3907   21.0    75
# 43                    Buick Century  22.4    6   231  110  3415   15.8    81
# 44         Buick Electra 225 Custom  12.0    8   455  225  4951   11.0    73
# 45       Buick Estate Wagon (Wagon)  14.0    8   455  225  3086   10.0    70
# 46       Buick Estate Wagon (Wagon)  16.9    8   350  155  4360   14.9    79
# 47             Buick Lesabre Custom  13.0    8   350  155  4502   13.5    72
# 48          Buick Opel Isuzu Deluxe  30.0    4   111   80  2155   14.8    77
# 49  Buick Regal Sport Coupe (Turbo)  17.7    6   231  165  3445   13.4    78
# 50                    Buick Skyhawk  21.0    6   231  110  3039   15.0    75
# 51                Buick Skylark 320  15.0    8   350  165  3693   11.5    70
# 52            Buick Skylark Limited  28.4    4   151   90  2670   16.0    79
# 53                    Buick Skylark  20.5    6   231  105  3425   16.9    77
# 54                    Buick Skylark  26.6    4   151   84  2635   16.4    81
# 55                Cadillac Eldorado  23.0    8   350  125  3900   17.4    79
# 56                 Cadillac Seville  16.5    8   350  180  4380   12.1    76
# 57        Chevroelt Chevelle Malibu  16.0    6   250  105  3897   18.5    75
# 58                Chevrolet Bel Air  15.0    8   350  145  4440   14.0    75
# 59                 Chevrolet Camaro  27.0    4   151   90  2950   17.3    82
# 60        Chevrolet Caprice Classic  13.0    8   400  150  4464   12.0    73
# 61        Chevrolet Caprice Classic  17.0    8   305  130  3840   15.4    79
#                                 ...   ...  ...   ...  ...   ...    ...   ...
#
# [392 rows x 8 columns]

# %%
cars.columns
# Out:
# Index([u'type', u'mpg', u'cyl', u'disp', u'hp', u'wt', u'speed', u'wt.1'], dtype='object')

# %% [markdown]
#     mpg  - fuel consumption
#     cyl  - the number of cylinders of the engine
#     disp -
#     hp   - horse power
#     wt   - weight of the car

# %% [markdown]
# ###Scatter plots

# %%
plot(cars['wt'], cars['mpg'], 'o') # the 'o' is for points
xlabel('weight')
ylabel('efficiency mpg')
title("Weight vs Efficiency for cars in the 70's and 80's")
show()

# %%
c4 = cars[cars['cyl'] == 4]
c6 = cars[cars['cyl'] == 6]
c8 = cars[cars['cyl'] == 8]

# %%
c4[:7]
# Out:
#              type   mpg  cyl  disp  hp    wt  speed  wt.1
# 7     AMC Concord  24.3    4   151  90  3003   20.1    80
# 28  AMC Spirit DL  27.4    4   121  80  2670   15.0    79
# 29    Audi 100 LS  20.0    4   114  91  2582   14.0    73
# 30    Audi 100 LS  23.0    4   115  95  2694   15.0    75
# 31    Audi 100 LS  24.0    4   107  90  2430   14.5    70
# 32      Audi 4000  34.3    4    97  78  2188   15.8    80
# 35       Audi Fox  29.0    4    98  83  2219   16.5    74
#
# [7 rows x 8 columns]

# %%
plot(c4['wt'], c4['mpg'], 'o', label='4 cyl')
plot(c6['wt'], c6['mpg'], 'o', label='6 cyl')
plot(c8['wt'], c8['mpg'], 'o', label='8 cyl')
legend()
show()

# %%
pa.__version__
# Out:
# '0.13.1'

# %%
c4.plot(kind='box') # this works on version 0.15.0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-c628503da0f3> in <module>()
# ----> 1 c4.plot(kind='box') # this works on version 0.15.0
#
# /usr/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in plot_frame(frame, x, y, subplots, sharex, sharey, use_index, figsize, grid, legend, rot, ax, style, title, xlim, ylim, logx, logy, xticks, yticks, kind, sort_columns, fontsize, secondary_y, **kwds)
#    1692         klass = ScatterPlot
#    1693     else:
# -> 1694         raise ValueError('Invalid chart type given %s' % kind)
#    1695
#    1696     if kind == 'scatter':
#
# ValueError: Invalid chart type given box

# %% [markdown]
# ###Line

# %%
names = pa.read_csv(os.path.join('data','names.csv'))
iris = pa.read_csv(os.path.join('data','iris.csv'))
names[:8]
# Out:
#    year       F       M
# 0  1880   90994  110492
# 1  1881   91955  100747
# 2  1882  107851  113687
# 3  1883  112322  104631
# 4  1884  129022  114445
# 5  1885  133056  107801
# 6  1886  144536  110786
# 7  1887  145982  101415
#
# [8 rows x 3 columns]

# %%
len(names)
# Out:
# 131

# %%
names.columns
# Out:
# Index([u'year', u'F', u'M'], dtype='object')

# %%
names['year'][:4]
# Out:
# 0    1880
# 1    1881
# 2    1882
# 3    1883
# Name: year, dtype: int64

# %%
plot(names['year'], names['M'])
plot(names['year'][::4], names['F'][::4],'-o', alpha=0.5)  #plot every 4th 
show()

# %% [markdown]
# ###Histograms

# %%
c4['wt'].hist(bins=10,alpha=0.4)
c4['wt'].hist(bins=20,alpha=0.4,color='r')
#c4['wt'].plot(kind='bar',bins=20)   # on version 0.15.0

# %% [markdown]
# ### Area plot with `kde`

# %%
density = stats.kde.gaussian_kde(c4['wt'])

# %%
xd = np.linspace(min(c4['wt'])-10, max(c4['wt'])+10, 100)
plot(xd, density(xd), lw=2, color='#FF7F00') #line
fill_between(xd, 0, density(xd), alpha=0.5, color='#FF7F00')
show()

# %%
c4['wt'].hist(bins=20,normed=1,alpha=0.4,color='r')
plot(xd, density(xd), lw=2, color='#FF7F00')
show()

# %% [markdown]
# ### Compare distributions

# %%
x1 = 100 + 15 * np.random.randn(100)
x2 = 50 + 10 * np.random.randn(100)

density1 = stats.kde.gaussian_kde(x1)
density2 = stats.kde.gaussian_kde(x2)

x = np.linspace(0, 150, 200)

# %%
plot(x,x, x, x*5)
# Out:
# [<matplotlib.lines.Line2D at 0x7f5ce771a290>,
#  <matplotlib.lines.Line2D at 0x7f5ce771a090>]

# %%
fill_between(x, 0, density1(x), alpha=0.5, color='#1B9E77')
fill_between(x, 0, density2(x), alpha=0.5, color='#D95F02')

plot([100,100],[0,density1(100)], color ='#1B9E77', linewidth=1, linestyle="--")
plot([50,50],[0,density2(50)], color ='#D95F02', linewidth=1, linestyle="--")
show()

# %% [markdown]
# ###Boxplots

# %%
data = [c4['mpg'],c6['mpg'],c8['mpg']]
boxplot(data, widths=0.65)
show()
#c4.boxplot('wt')

# %% [markdown]
# ###Bar

# %%
w = 0.3
means = [c4['mpg'].mean(), 
         c6['mpg'].mean(), 
         c8['mpg'].mean()]
ind = np.arange(3) + w

# %%
bar( ind, means, color='#377EB8', width=w, alpha=0.5)
xticks(ind+w/2., ('G1', 'G2', 'G3') )
show()

# %% [markdown]
# ###Stacked bar
#
# Ref: [matplotlib examples](http://matplotlib.org/examples/pylab_examples/bar_stacked.html)

# %%
N = 5
menMeans   = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)

ind = np.arange(N)+0.1    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

bar(ind, menMeans,   width, color='#1B9E77', label='men')
bar(ind, womenMeans, width, color='#D95F02', bottom=menMeans, label='women')

ylabel('Scores')
title('Scores by group and gender')
xticks(ind+width/2., ('G1', 'G2', 'G3', 'G4', 'G5') )
yticks(np.arange(0,81,10))
legend()
show()
